# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Single Numeric Features

# %%
from smarttoolsml.eda_visualisations.single_numeric_fea import boxplot

# single boxplot

series = df["Age"]
boxplot.plot_single_boxplot(df_series=series)

# %%
# multi boxplot

columns = ["Age", "Fare"]
boxplot.plot_multi_boxplot(df=df, columns=columns)

# %%
from smarttoolsml.eda_visualisations.single_numeric_fea import histogram

# single histogram

df_series = df["Age"]
histogram.plot_single_hist(df_series=df_series)

# %%
# multi hist

columns = ["Age", "Fare"]
histogram.plot_multi_hist(df=df, columns=columns)

# %%
from smarttoolsml.eda_visualisations.single_numeric_fea import kde

# single kde

df_series = df["Age"]
kde.plot_single_kde(df_series=df_series)

# %%
# multi kde

columns = ["Age", "Fare"]
kde.plot_multi_kde(df=df, columns=columns)

# %% [markdown]
# # 2. Single Categorical Feature

# %%
from smarttoolsml.eda_visualisations.single_categorical_fea import countplot

# single countplot

x = "Survived"
countplot.plot_single_countplot(df=df, x=x)

# %%
# multi countplot

columns = ["Survived", "Pclass", "Sex", "SibSp", "Parch", "Embarked"]
countplot.plot_multi_countplot(df=df, columns=columns)

# %% [markdown]
# # 3. Two Numeric Features

# %%
from smarttoolsml.eda_visualisations.two_numeric_fea import scatterplot

# Scatterplot

x = "Age"
y = "Fare"
scatterplot.plot_single_scatterplot(df=df, x=x, y=y)

# %%
from smarttoolsml.eda_visualisations.two_numeric_fea import lineplot

# Lineplot

x = "Age"
y = "Fare"
lineplot.plot_single_lineplot(df=df, x=x, y=y, figsize=(10, 5))

# %% [markdown]
# # 4. Two Categorical Features

# %%
from smarttoolsml.eda_visualisations.two_categorical_fea import countplot

# Single Countplot

x = "Sex"
hue = "Survived"
countplot.plot_single_countplot(df=df, x=x, hue=hue)

# %%
# Multi Countplot

columns = ["Sex", "Pclass"]
hue = "Survived"
countplot.plot_multi_countplot(df=df, columns=columns, hue=hue)

# %% [markdown]
# # 5. One Numeric and One Categorical Feature

# %%
from smarttoolsml.eda_visualisations.one_numeric_one_categorical_fea import boxplot

# single boxplot

x = "Sex"
y = "Age"
boxplot.plot_single_boxplot(df=df, x=x, y=y)

# %%
# multi boxplot

x_cols = ["Sex", "Pclass"]
y = "Age"

boxplot.plot_multi_boxplot(df=df, x_cols=x_cols, y=y)

# %%
# single violinplot

x = "Sex"
y = "Age"
kind = "violin"

boxplot.plot_single_boxplot(df=df, x=x, y=y, kind=kind)

# %%
# multi violinplot

x_cols = ["Sex", "Pclass"]
y = "Age"
kind = "violin"

boxplot.plot_multi_boxplot(df=df, x_cols=x_cols, y=y, kind=kind)

# %% [markdown]
# # 6. Multidimensional Features

# %%
from smarttoolsml.eda_visualisations.multi_fea import scatterplot

# Scatterplot 3 Features

x = "Age"
y = "Fare"
hue = "Survived"
scatterplot.plot__scatterplot_3f(df=df, x=x, y=y, hue=hue)

# %%
# Scatterplot 4 Features

x = "Age"
y = "Fare"
hue = "Survived"
size = "Sex"
scatterplot.plot_scatterplot_4f(df=df, x=x, y=y, hue=hue, size=size)

# %%
# Scatterplot 5 Features

x = "Age"
y = "Fare"
hue = "Survived"
size = "Sex"
style = "Pclass"
scatterplot.plot_scatterplot_5f(df=df, x=x, y=y, hue=hue, size=size, style=style)

# %%
from smarttoolsml.eda_visualisations.multi_fea import boxplot

# Boxplot 3 Features

x = "Survived"
y = "Age"
hue = "Pclass"

boxplot.plot_boxplot_3f(df=df, x=x, y=y, hue=hue)

# %%
# Violinplot 3 Features

x = "Survived"
y = "Age"
hue = "Pclass"
kind = "violin"

boxplot.plot_boxplot_3f(df=df, x=x, y=y, hue=hue, kind=kind)

# %%
from smarttoolsml.eda_visualisations.multi_fea import pairplot

# Pairplot

hue = "Survived"
pairplot.plot_pairplot(df=df, hue=hue, diag_kind="kde")

# %%
from smarttoolsml.eda_visualisations.multi_fea import heatmap

# Correlation Heatmap

heatmap.plot_corr_heatmap(df=df, figsize=(10, 5), fmt=".2f")
